# %%
import numpy as np

# %%
#filename = "/cluster/home/wueestm/f3loc/evol_path/hge_customized_cropped/gt/pretty_filter_extended/results.pkl"
#filename = "/cluster/home/wueestm/f3loc/evol_path/hge_customized_complete/gt/pretty_filter_extended/results.pkl"

#filename = "/cluster/home/wueestm/f3loc/evol_path/hge_customized_cropped/f3loc_own/pretty_filter_extended/results.pkl"
#filename = "/cluster/home/wueestm/f3loc/evol_path/hge_customized_complete/f3loc_own/pretty_filter_extended/results.pkl"

#filename = "/cluster/home/wueestm/f3loc/evol_path/hge_customized_cropped/metric3d_percentile_95/pretty_filter_extended/results.pkl"
#filename = "/cluster/home/wueestm/f3loc/evol_path/hge_customized_complete/metric3d_percentile_95/pretty_filter_extended/results.pkl"

#filename = "/cluster/home/wueestm/f3loc/evol_path/hge_customized_cropped/metric3d_attention/pretty_filter_extended/results.pkl"
#filename = "/cluster/home/wueestm/f3loc/evol_path/hge_customized_complete/metric3d_attention/pretty_filter_extended/results.pkl"

#filename = "/cluster/home/wueestm/f3loc/evol_path/gibson_t/gt/pretty_filter_extended/results.pkl"
filename = "/cluster/home/wueestm/f3loc/evol_path/gibson_t/f3loc_provided/pretty_filter_extended/results.pkl"
#filename = "/cluster/home/wueestm/f3loc/evol_path/gibson_t/metric3d_percentile_95/pretty_filter_extended/results.pkl"

results_dict = np.load(filename, allow_pickle=True)

# %%
results_dict = np.load(filename, allow_pickle=True)

# %%
results_dict.keys()
# Out:
# dict_keys(['per_frame', 'per_seq', 'overall'])

# %%
results_dict["overall"]
# Out:
# {'mean_mean_depth_MAE': 2.5316684713857556,
#  'mean_mean_depth_cos_sim': 0.8131550620088142,
#  'mean_mean_ray_MAE': 0.8559512356496228,
#  'mean_mean_obs_pos_err': 5.477989018069436,
#  'mean_mean_obs_orn_err': 89.99354480648843,
#  'mean_mean_post_pos_err': 4.6135907,
#  'mean_mean_post_orn_err': 84.68458635301648,
#  'mean_recalls': array([2.78629145e-04, 3.62217888e-03, 1.44887155e-02, 4.45806631e-03,
#         8.49818891e-02, 4.74505433e-01, 9.29228197e-01]),
#  'mean_successes': array([0.16216216, 0.05405405, 0.05405405, 0.02702703]),
#  'mean_RMSEs': 4.666671173208072}

# %%
results_dict["per_frame"]
# Out:
# {'metric_depth_l1_loss_ls_ls': [[6.471909046173096,
#    4.350529193878174,
#    4.733366012573242,
#    2.2857041358947754,
#    1.8816817998886108,
#    1.5952285528182983,
#    7.184154033660889,
#    2.267568826675415,
#    1.2579034566879272,
#    1.991736650466919,
#    2.4488754272460938,
#    3.401097297668457,
#    5.874903202056885,
#    2.554189443588257,
#    1.5816000699996948,
#    0.46901875734329224,
#    0.58091139793396,
#    0.5624211430549622,
#    1.6385619640350342,
#    3.10378360748291,
#    1.8618817329406738,
#    2.506223678588867,
#    2.7050957679748535,
#    2.55725359916687,
#    0.8386334776878357,
#    1.0227138996124268,
#    2.2758140563964844,
#    2.822882652282715,
#    2.452122926712036,
#    2.560025930404663,
#    2.214308738708496,
#    1.2893625497817993,
#    1.0003184080123901,
#    1.1103687286376953,
#    1.443887710571289,
#    0.5382986664772034,
#    0.85823655128479,
#    2.6711463928222656,
#    4.117246150970459,
# ...
